# %%
#Question : Write a program in Python to allow the error of syntax to go in exception. HINT: use SyntaxError 

#while True:
#   try:
#       x = int(input("Please enter a number: "))
#       break
#   except ValueError:
#       print("Oops!  That was no valid number.  Try again...")
        
#Question: Write a program in Python to allow user to open a file by using argv module. If the entered name is incorrect throw an exception and ask them to enter the name again. Make sure to use read only mode.  

# import sys
# print('program running')
# filename=sys.argv[1]
# while True:
#     try:
#         fhand=open(filename,'r')
#         print(fhand.read())
#         print('you are in try block')
#         break
#     except:
#         filename=input('Enter the file name again :')
#         print('wrong file name, please enter correct file name')
#         continue

#Question: Write a program to handle an error if the user entered the number more than four digits it should return “Please length is too short/long !!! Please provide only four digits”  

# Input=input('Enter the number')
# while True:
#     if len(number)!=4:
#         raise ValueError('Length is short/long & please enter correct number')
#         else:
#     print('Proper Entry')
#         break



#Question: Create a login page backend to ask user to enter the UserEmail and password. Make sure to ask Re-Type Password and if the password is incorrect give chance to enter it again but it should not be more than 3 times. 

#print('Enter correct username and password combo to continue')
#count=0
#while count < 3:
#    username = input('Enter username: ')
#    password = input('Enter password: ')
#    if password=='JklMno' and username=='Divya':
#        print('Access granted')
#        break
#    else:
#        print('Access denied. Try again.')
#        count += 1

#Question: https://www.programiz.com/python-programming/exception-handling Go through this link to understand Finally and Raise concept. 

#Question: Read any file using Python File handling concept and return only the even length string from the doc.txt file. 
#Consider the content as:  

#Hello I am a file  

#Where you need to return the data string  

#Which is of even length  

#Make sure you return the content in  

#The same link as it is present. 

# try:
#    b=open("data.txt","r")
#    for i in b:
#        if len(i)%2==0:
#            print (i, "length ->" ,len (i))
# finally:
#   b.close()
